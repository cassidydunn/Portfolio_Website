# %%
#Note: Some data is not shown in the output for privacy of the company.

import pandas as pd
#reading in data from excel
df = pd.read_excel("nlp_data_v3.xlsx")

# %%
#Importing packages needed
import numpy as np
import pickle as pk
import warnings

#Don't need to see certain warnings so we will filter them out
warnings.filterwarnings("ignore")

# %%
#Importing some more needed packages
from bs4 import BeautifulSoup
import unicodedata
import re

# %%
#Importing more packages and certain words that will be used in the models
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk import ne_chunk
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cdunn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cdunn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cdunn\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\cdunn\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\cdunn\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
#Showing the top 5 rows of the current dataframe
df.head()
# Out:
#       Item_Number                                             Review  Rating
# 0    164BARBISTRO  I really like how the mahogany color added mor...       5
# 1       369MJCFSD  What a superb fryer! Your company is great to ...       5
# 2        35340520  I read about this knife at americastestkithen....       5
# 3  977670001   BX    The spoons have a nice weight and feel to them.       5
# 4        95381007                            Dripless, great candle!       5

# %%
#Changing the dataframe to only include the rating and review
df = df[['Rating','Review']]
df.head()
# Out:
#    Rating                                             Review
# 0       5  I really like how the mahogany color added mor...
# 1       5  What a superb fryer! Your company is great to ...
# 2       5  I read about this knife at americastestkithen....
# 3       5    The spoons have a nice weight and feel to them.
# 4       5                            Dripless, great candle!

# %%
#Viewing one specific review
df['Review'].iloc[0]
# Out:
# 'I really like how the mahogany color added more style to my kitchen island, more than a normal stool would have. Very durable, I really like them.'

# %%
#Confirming the data types that we have
df.dtypes
# Out:
# Rating     int64
# Review    object
# dtype: object

# %%
#Chanigng review to a string instead
df['Review'] = df['Review'].astype(str)

# %%
#Creating functions for the imported text
def remove_html_tags_func(text):
    '''
    Removes HTML-Tags from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without HTML-Tags
    ''' 
    return BeautifulSoup(text, 'html.parser').get_text()

# %%
def remove_url_func(text):
    '''
    Removes URL addresses from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without URL addresses
    ''' 
    return re.sub(r'https?://\S+|www\.\S+', '', text)

# %%
def remove_accented_chars_func(text):
    '''
    Removes all accented characters from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without accented characters
    '''
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

# %%
def remove_punctuation_func(text):
    '''
    Removes all punctuation from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without punctuations
    '''
    return re.sub(r'[^a-zA-Z0-9]', ' ', text)

# %%
def remove_irr_char_func(text):
    '''
    Removes all irrelevant characters (numbers and punctuation) from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without irrelevant characters
    '''
    return re.sub(r'[^a-zA-Z]', ' ', text)

# %%
def remove_extra_whitespaces_func(text):
    '''
    Removes extra whitespaces from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without extra whitespaces
    ''' 
    return re.sub(r'^\s*|\s\s*', ' ', text).strip()

# %%
def word_count_func(text):
    '''
    Counts words within a string
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Number of words within a string, integer
    ''' 
    return len(text.split())

# %%
#Applying the functions and cleaning the reviews to make it easier to input into the model
df['Clean_Reviews'] = df['Review'].str.lower()
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_html_tags_func)
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_url_func)
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_accented_chars_func)
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_punctuation_func)
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_irr_char_func)
df['Clean_Reviews'] = df['Clean_Reviews'].apply(remove_extra_whitespaces_func)

df.head()
# Out:
#    Rating                                             Review  \
# 0       5  I really like how the mahogany color added mor...
# 1       5  What a superb fryer! Your company is great to ...
# 2       5  I read about this knife at americastestkithen....
# 3       5    The spoons have a nice weight and feel to them.
# 4       5                            Dripless, great candle!
#
#                                        Clean_Reviews
# 0  i really like how the mahogany color added mor...
# 1  what a superb fryer your company is great to w...
# 2  i read about this knife at americastestkithen ...
# 3     the spoons have a nice weight and feel to them
# 4                              dripless great candle

# %%
#Counting how many words are in each review
df['Word_Count'] = df['Clean_Reviews'].apply(word_count_func)

# %%
#Showing the top 5 with teh word count and clean reviews
df[['Clean_Reviews', 'Word_Count']].head()
# Out:
#                                        Clean_Reviews  Word_Count
# 0  i really like how the mahogany color added mor...          27
# 1  what a superb fryer your company is great to w...          27
# 2  i read about this knife at americastestkithen ...          62
# 3     the spoons have a nice weight and feel to them          10
# 4                              dripless great candle           3

# %%
#Understanding the average amount of words used
print('Average of words counted: ' + str(df['Word_Count'].mean()))
# Out:
# Average of words counted: 38.0592

# %%
#Saving the data that we currently have and then putting it to a csv
pk.dump(clean_text, open('clean_text.pkl', 'wb'))

df.to_csv('reviewTest.csv', index = False)

# %%
#creating a function to remove the english stop words (such as 'a','is' - common words that are not going to contribute to the model)
def remove_english_stopwords_func(text):
    '''
    Removes Stop Words (also capitalized) from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without Stop Words
    ''' 
    # check in lowercase 
    t = [token for token in text if token.lower() not in stopwords.words("english")]
    text = ' '.join(t)    
    return text

# %%
#Adjusting the attribute of the dataframe
pd.set_option('display.max_colwidth', 30)

# %%
#Applying the function to tokenize the words - this splits the reviews into smaller parts so it can be understood in an easier way

df['Reviews_Tokenized'] = df['Clean_Reviews'].apply(word_tokenize)

df.head()
# Out:
#    Rating                         Review                  Clean_Reviews  \
# 0       5  I really like how the maho...  i really like how the maho...
# 1       5  What a superb fryer! Your ...  what a superb fryer your c...
# 2       5  I read about this knife at...  i read about this knife at...
# 3       5  The spoons have a nice wei...  the spoons have a nice wei...
# 4       5        Dripless, great candle!          dripless great candle
#
#    Word_Count              Reviews_Tokenized
# 0          27  [i, really, like, how, the...
# 1          27  [what, a, superb, fryer, y...
# 2          62  [i, read, about, this, kni...
# 3          10  [the, spoons, have, a, nic...
# 4           3      [dripless, great, candle]

# %%
#Seeing how many tokens are used
df['Token_Count'] = df['Reviews_Tokenized'].str.len()

df.head()
# Out:
#    Rating                         Review                  Clean_Reviews  \
# 0       5  I really like how the maho...  i really like how the maho...
# 1       5  What a superb fryer! Your ...  what a superb fryer your c...
# 2       5  I read about this knife at...  i read about this knife at...
# 3       5  The spoons have a nice wei...  the spoons have a nice wei...
# 4       5        Dripless, great candle!          dripless great candle
#
#    Word_Count              Reviews_Tokenized  Token_Count
# 0          27  [i, really, like, how, the...           27
# 1          27  [what, a, superb, fryer, y...           27
# 2          62  [i, read, about, this, kni...           62
# 3          10  [the, spoons, have, a, nic...           10
# 4           3      [dripless, great, candle]            3

# %%
#Seeing if there is much change after tokenization
print('Average of words counted: ' + str(df['Word_Count'].mean()))
print('Average of tokens counted: ' + str(df['Token_Count'].mean()))
# Out:
# Average of words counted: 38.0592
# Average of tokens counted: 38.0684

# %%
#Seeing the difference between them in an easier way to understand
df_subset = df[['Clean_Reviews', 'Word_Count', 'Reviews_Tokenized', 'Token_Count']]
df_subset['Diff'] = df_subset['Token_Count'] - df_subset['Word_Count']

#Only want to see where it does not equal 0 and there actually is a difference
df_subset = df_subset[(df_subset["Diff"] != 0)]
df_subset.sort_values(by='Diff', ascending=False)
# Out:
#                       Clean_Reviews  Word_Count  \
# 90    i am pleased to have saved...          26
# 1656  these are a little difficu...          29
# 2220  the photo of the dispenser...          58
# 2205  i was very disappointed in...         434
# 2179  the suction on this produc...          28
# 2168  i cannot believe that anyo...          50
# 2067  i thought the bottle would...          25
# 2007  it broke within weeks manu...          23
# 1896  the picture displayed for ...         111
# 1737  i cannot give this soap di...          50
# 1714  waited for a month to rece...         216
# 1644  the reason i gave this two...          49
# 319   this is a wonderful produc...          40
# 1600  the basics of the plastic ...          29
# 1414  the price of this item can...          50
# 1396  this is exactly as i suspe...          28
# 1385  i like using these rather ...          44
# 1252  this worked well the first...          48
# 1223  now this is the basic knif...          53
# 1071  never used them cannot fin...          31
# 1064  i purchased this product i...          67
# 628   these spoons are wonderful...          25
# 2311  bulbs too dim and too yell...         112
#
#                   Reviews_Tokenized  Token_Count  Diff
# 90    [i, am, pleased, to, have,...           27     1
# 1656  [these, are, a, little, di...           30     1
# 2220  [the, photo, of, the, disp...           59     1
# 2205  [i, was, very, disappointe...          435     1
# 2179  [the, suction, on, this, p...           29     1
# 2168  [i, can, not, believe, tha...           51     1
# 2067  [i, thought, the, bottle, ...           26     1
# 2007  [it, broke, within, weeks,...           24     1
# 1896  [the, picture, displayed, ...          112     1
# 1737  [i, can, not, give, this, ...           51     1
# 1714  [waited, for, a, month, to...          217     1
# 1644  [the, reason, i, gave, thi...           50     1
# 319   [this, is, a, wonderful, p...           41     1
# 1600  [the, basics, of, the, pla...           30     1
# 1414  [the, price, of, this, ite...           51     1
# 1396  [this, is, exactly, as, i,...           29     1
# 1385  [i, like, using, these, ra...           45     1
# 1252  [this, worked, well, the, ...           49     1
# 1223  [now, this, is, the, basic...           54     1
# 1071  [never, used, them, can, n...           32     1
# 1064  [i, purchased, this, produ...           68     1
# 628   [these, spoons, are, wonde...           26     1
# 2311  [bulbs, too, dim, and, too...          113     1

# %%
#Confirming one
df_subset['Clean_Reviews'].iloc[2]
# Out:
# 'these spoons are wonderful they look like the real thing and i cannot wait to use them for my wedding reception they are beautiful spoons'

# %%
#Seeing how the tokenization worked and comparing it with statement above
df_subset['Reviews_Tokenized'].iloc[2]
# Out:
# ['these',
#  'spoons',
#  'are',
#  'wonderful',
#  'they',
#  'look',
#  'like',
#  'the',
#  'real',
#  'thing',
#  'and',
#  'i',
#  'can',
#  'not',
#  'wait',
#  'to',
#  'use',
#  'them',
#  'for',
#  'my',
#  'wedding',
#  'reception',
#  'they',
#  'are',
#  'beautiful',
#  'spoons']

# %%
#Applying the function to remove the english stop words
df['Reviews_wo_Stop_Words'] = df['Reviews_Tokenized'].apply(remove_english_stopwords_func)

df.head()
# Out:
#    Rating                         Review                  Clean_Reviews  \
# 0       5  I really like how the maho...  i really like how the maho...
# 1       5  What a superb fryer! Your ...  what a superb fryer your c...
# 2       5  I read about this knife at...  i read about this knife at...
# 3       5  The spoons have a nice wei...  the spoons have a nice wei...
# 4       5        Dripless, great candle!          dripless great candle
#
#    Word_Count              Reviews_Tokenized  Token_Count  \
# 0          27  [i, really, like, how, the...           27
# 1          27  [what, a, superb, fryer, y...           27
# 2          62  [i, read, about, this, kni...           62
# 3          10  [the, spoons, have, a, nic...           10
# 4           3      [dripless, great, candle]            3
#
#            Reviews_wo_Stop_Words
# 0  really like mahogany color...
# 1  superb fryer company great...
# 2  read knife americastestkit...
# 3        spoons nice weight feel
# 4          dripless great candle

# %%
#Looking at the word count again
df['Word_Count_wo_Stop_Words'] = df['Reviews_wo_Stop_Words'].apply(word_count_func)

df.head().T
# Out:
#                                                       0  \
# Rating                                                5
# Review                    I really like how the maho...
# Clean_Reviews             i really like how the maho...
# Word_Count                                           27
# Reviews_Tokenized         [i, really, like, how, the...
# Token_Count                                          27
# Reviews_wo_Stop_Words     really like mahogany color...
# Word_Count_wo_Stop_Words                             14
#
#                                                       1  \
# Rating                                                5
# Review                    What a superb fryer! Your ...
# Clean_Reviews             what a superb fryer your c...
# Word_Count                                           27
# Reviews_Tokenized         [what, a, superb, fryer, y...
# Token_Count                                          27
# Reviews_wo_Stop_Words     superb fryer company great...
# Word_Count_wo_Stop_Words                             12
#
#                                                       2  \
# Rating                                                5
# Review                    I read about this knife at...
# Clean_Reviews             i read about this knife at...
# Word_Count                                           62
# Reviews_Tokenized         [i, read, about, this, kni...
# Token_Count                                          62
# Reviews_wo_Stop_Words     read knife americastestkit...
# Word_Count_wo_Stop_Words                             42
#
#                                                       3  \
# Rating                                                5
# Review                    The spoons have a nice wei...
# Clean_Reviews             the spoons have a nice wei...
# Word_Count                                           10
# Reviews_Tokenized         [the, spoons, have, a, nic...
# Token_Count                                          10
# Reviews_wo_Stop_Words           spoons nice weight feel
# Word_Count_wo_Stop_Words                              4
#
#                                                   4
# Rating                                            5
# Review                      Dripless, great candle!
# Clean_Reviews                 dripless great candle
# Word_Count                                        3
# Reviews_Tokenized         [dripless, great, candle]
# Token_Count                                       3
# Reviews_wo_Stop_Words         dripless great candle
# Word_Count_wo_Stop_Words                          3

# %%
##part3 - working more with the actual NLP models

# %%
#Defining a function to use stemming - this reduces wods to their root or base form
def norm_stemming_func(text):
    '''
    Stemming tokens from string
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use PorterStemmer() to stem the created tokens
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with stemmed words
    '''  
    words = word_tokenize(text)
    text = ' '.join([PorterStemmer().stem(word) for word in words])
    return text

# %%
#Defining a function for lemmatization - also breaks down a word to its root meaning to identify similarities
def norm_lemm_func(text):
    '''
    Lemmatize tokens from string
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use WordNetLemmatizer() to lemmatize the created tokens
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with lemmatized words
    '''  
    words = word_tokenize(text)
    text = ' '.join([WordNetLemmatizer().lemmatize(word) for word in words])
    return text

# %%
def norm_lemm_v_func(text):
    '''
    Lemmatize tokens from string 
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use WordNetLemmatizer() to lemmatize the created tokens
            POS tag is set to 'v' for verb
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with lemmatized words
    '''  
    words = word_tokenize(text)
    text = ' '.join([WordNetLemmatizer().lemmatize(word, pos='v') for word in words])
    return text

# %%
def norm_lemm_a_func(text):
    '''
    Lemmatize tokens from string
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use WordNetLemmatizer() to lemmatize the created tokens
            POS tag is set to 'a' for adjective
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with lemmatized words
    ''' 
    words = word_tokenize(text)
    text = ' '.join([WordNetLemmatizer().lemmatize(word, pos='a') for word in words])
    return text

# %%
def get_wordnet_pos_func(word):
    '''
    Maps the respective POS tag of a word to the format accepted by the lemmatizer of wordnet
    
    Args:
        word (str): Word to which the function is to be applied, string
    
    Returns:
        POS tag, readable for the lemmatizer of wordnet
    '''     
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
def norm_lemm_POS_tag_func(text):
    '''
    Lemmatize tokens from string
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use WordNetLemmatizer() to lemmatize the created tokens
            POS tag is determined with the help of function get_wordnet_pos()
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with lemmatized words
    ''' 
    words = word_tokenize(text)
    text = ' '.join([WordNetLemmatizer().lemmatize(word, get_wordnet_pos_func(word)) for word in words])
    return text

# %%
def norm_lemm_v_a_func(text):
    '''
    Lemmatize tokens from string
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Use WordNetLemmatizer() with POS tag 'v' to lemmatize the created tokens
    Step 3: Use word_tokenize() to get tokens from generated string        
    Step 4: Use WordNetLemmatizer() with POS tag 'a' to lemmatize the created tokens
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with lemmatized words
    '''
    words1 = word_tokenize(text)
    text1 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='v') for word in words1])
    words2 = word_tokenize(text1)
    text2 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='a') for word in words2])
    return text2

# %%
#Applying the lemmatization function and seeing the word count

df['Reviews_lemmatized'] = df['Reviews_wo_Stop_Words'].apply(norm_lemm_v_a_func)

df['Word_Count_lemmatized_Reviews'] = df['Reviews_lemmatized'].apply(word_count_func)

df.head(3).T
# Out:
#                                                            0  \
# Rating                                                     5
# Review                         I really like how the maho...
# Clean_Reviews                  i really like how the maho...
# Word_Count                                                27
# Reviews_Tokenized              [i, really, like, how, the...
# Token_Count                                               27
# Reviews_wo_Stop_Words          really like mahogany color...
# Word_Count_wo_Stop_Words                                  14
# Reviews_lemmatized             really like mahogany color...
# Word_Count_lemmatized_Reviews                             14
#
#                                                            1  \
# Rating                                                     5
# Review                         What a superb fryer! Your ...
# Clean_Reviews                  what a superb fryer your c...
# Word_Count                                                27
# Reviews_Tokenized              [what, a, superb, fryer, y...
# Token_Count                                               27
# Reviews_wo_Stop_Words          superb fryer company great...
# Word_Count_wo_Stop_Words                                  12
# Reviews_lemmatized             superb fryer company great...
# Word_Count_lemmatized_Reviews                             12
#
#                                                            2
# Rating                                                     5
# Review                         I read about this knife at...
# Clean_Reviews                  i read about this knife at...
# Word_Count                                                62
# Reviews_Tokenized              [i, read, about, this, kni...
# Token_Count                                               62
# Reviews_wo_Stop_Words          read knife americastestkit...
# Word_Count_wo_Stop_Words                                  42
# Reviews_lemmatized             read knife americastestkit...
# Word_Count_lemmatized_Reviews                             42

# %%
#Defining another function that removes single characters from the string
def remove_single_char_func(text, threshold=1):
    '''
    Removes single characters from string, if present
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Removes words whose length falls below the threshold (by default = 1)
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        String with removed words whose length was below the threshold (by default = 1)
    ''' 
    threshold = threshold
    
    words = word_tokenize(text)
    text = ' '.join([word for word in words if len(word) > threshold])
    return text

# %%
#Applying the function and looking at the word count - don't want to remove too much that it becomes unclear
df['Reviews_cleaned_wo_single_char'] = df['Reviews_lemmatized'].apply(remove_single_char_func)

df['Word_Count_cleaned_Reviews_wo_single_char'] = df['Reviews_cleaned_wo_single_char'].apply(word_count_func)

df.head(3).T
# Out:
#                                                             0  \
# Rating                                                      5
# Review                          I really like how the maho...
# Clean_Reviews                   i really like how the maho...
# Word_Count                                                 27
# Reviews_Tokenized               [i, really, like, how, the...
# Token_Count                                                27
# Reviews_wo_Stop_Words           really like mahogany color...
# Word_Count_wo_Stop_Words                                   14
# Reviews_lemmatized              really like mahogany color...
# Word_Count_lemmatized_Reviews                              14
# Reviews_cleaned_wo_single_char  really like mahogany color...
# Word_Count_cleaned_Reviews_...                             14
#
#                                                             1  \
# Rating                                                      5
# Review                          What a superb fryer! Your ...
# Clean_Reviews                   what a superb fryer your c...
# Word_Count                                                 27
# Reviews_Tokenized               [what, a, superb, fryer, y...
# Token_Count                                                27
# Reviews_wo_Stop_Words           superb fryer company great...
# Word_Count_wo_Stop_Words                                   12
# Reviews_lemmatized              superb fryer company great...
# Word_Count_lemmatized_Reviews                              12
# Reviews_cleaned_wo_single_char  superb fryer company great...
# Word_Count_cleaned_Reviews_...                             12
#
#                                                             2
# Rating                                                      5
# Review                          I read about this knife at...
# Clean_Reviews                   i read about this knife at...
# Word_Count                                                 62
# Reviews_Tokenized               [i, read, about, this, kni...
# Token_Count                                                62
# Reviews_wo_Stop_Words           read knife americastestkit...
# Word_Count_wo_Stop_Words                                   42
# Reviews_lemmatized              read knife americastestkit...
# Word_Count_lemmatized_Reviews                              42
# Reviews_cleaned_wo_single_char  read knife americastestkit...
# Word_Count_cleaned_Reviews_...                             42

# %%
#Looking at the average number of words in comparison
print('Average of lemmatized words counted: ' + str(df['Word_Count_lemmatized_Reviews'].mean()))
print('Average of cleaned words wo single char counted: ' + str(df['Word_Count_cleaned_Reviews_wo_single_char'].mean()))
# Out:
# Average of lemmatized words counted: 18.2792
# Average of cleaned words wo single char counted: 18.2544

# %%
#Looking at the difference in an easier way and only focusing on where there is a difference
df_subset = df[['Reviews_lemmatized', 'Word_Count_lemmatized_Reviews', 
                'Reviews_cleaned_wo_single_char', 'Word_Count_cleaned_Reviews_wo_single_char']]

df_subset['Diff'] = df_subset['Word_Count_lemmatized_Reviews'] - \
                    df_subset['Word_Count_cleaned_Reviews_wo_single_char']


df_subset = df_subset[(df_subset["Diff"] != 0)]
df_subset = df_subset.sort_values(by='Diff', ascending=False)
df_subset.head().T
# Out:
#                                                          1637  \
# Reviews_lemmatized              buy blender happy price ma...
# Word_Count_lemmatized_Reviews                              87
# Reviews_cleaned_wo_single_char  buy blender happy price ma...
# Word_Count_cleaned_Reviews_...                             84
# Diff                                                        3
#
#                                                          507   \
# Reviews_lemmatized              nice pan usable area x adv...
# Word_Count_lemmatized_Reviews                              22
# Reviews_cleaned_wo_single_char  nice pan usable area adver...
# Word_Count_cleaned_Reviews_...                             20
# Diff                                                        2
#
#                                                          1356  \
# Reviews_lemmatized              work great price great siz...
# Word_Count_lemmatized_Reviews                              14
# Reviews_cleaned_wo_single_char  work great price great siz...
# Word_Count_cleaned_Reviews_...                             12
# Diff                                                        2
#
#                                                          1289  \
# Reviews_lemmatized              one time purchase b b gues...
# Word_Count_lemmatized_Reviews                              14
# Reviews_cleaned_wo_single_char  one time purchase guest re...
# Word_Count_cleaned_Reviews_...                             12
# Diff                                                        2
#
#                                                          1257
# Reviews_lemmatized              bite problem quality great...
# Word_Count_lemmatized_Reviews                              38
# Reviews_cleaned_wo_single_char  bite problem quality great...
# Word_Count_cleaned_Reviews_...                             36
# Diff                                                        2

# %%
#Applying the function and word count to remove a single character
df["Reviews_cleaned_wo_char_length_2"] = df.apply(lambda x: remove_single_char_func(x["Reviews_lemmatized"], 
                                                            threshold=2), axis = 1)

df['Word_Count_cleaned_Reviews_wo_char_length_2'] = df['Reviews_cleaned_wo_char_length_2'].apply(word_count_func)

df.head(3).T
# Out:
#                                                             0  \
# Rating                                                      5
# Review                          I really like how the maho...
# Clean_Reviews                   i really like how the maho...
# Word_Count                                                 27
# Reviews_Tokenized               [i, really, like, how, the...
# Token_Count                                                27
# Reviews_wo_Stop_Words           really like mahogany color...
# Word_Count_wo_Stop_Words                                   14
# Reviews_lemmatized              really like mahogany color...
# Word_Count_lemmatized_Reviews                              14
# Reviews_cleaned_wo_single_char  really like mahogany color...
# Word_Count_cleaned_Reviews_...                             14
# Reviews_cleaned_wo_char_len...  really like mahogany color...
# Word_Count_cleaned_Reviews_...                             14
#
#                                                             1  \
# Rating                                                      5
# Review                          What a superb fryer! Your ...
# Clean_Reviews                   what a superb fryer your c...
# Word_Count                                                 27
# Reviews_Tokenized               [what, a, superb, fryer, y...
# Token_Count                                                27
# Reviews_wo_Stop_Words           superb fryer company great...
# Word_Count_wo_Stop_Words                                   12
# Reviews_lemmatized              superb fryer company great...
# Word_Count_lemmatized_Reviews                              12
# Reviews_cleaned_wo_single_char  superb fryer company great...
# Word_Count_cleaned_Reviews_...                             12
# Reviews_cleaned_wo_char_len...  superb fryer company great...
# Word_Count_cleaned_Reviews_...                             12
#
#                                                             2
# Rating                                                      5
# Review                          I read about this knife at...
# Clean_Reviews                   i read about this knife at...
# Word_Count                                                 62
# Reviews_Tokenized               [i, read, about, this, kni...
# Token_Count                                                62
# Reviews_wo_Stop_Words           read knife americastestkit...
# Word_Count_wo_Stop_Words                                   42
# Reviews_lemmatized              read knife americastestkit...
# Word_Count_lemmatized_Reviews                              42
# Reviews_cleaned_wo_single_char  read knife americastestkit...
# Word_Count_cleaned_Reviews_...                             42
# Reviews_cleaned_wo_char_len...  read knife americastestkit...
# Word_Count_cleaned_Reviews_...                             42

# %%
#Comparing the average number of words again
print('Average of lemmatized words counted: ' + str(df['Word_Count_lemmatized_Reviews'].mean()))
print('Average of cleaned words wo single char counted: ' + str(df['Word_Count_cleaned_Reviews_wo_single_char'].mean()))
print('Average of cleaned words wo char length 2 counted: ' + str(df['Word_Count_cleaned_Reviews_wo_char_length_2'].mean()))
# Out:
# Average of lemmatized words counted: 18.2792
# Average of cleaned words wo single char counted: 18.2544
# Average of cleaned words wo char length 2 counted: 18.0604

# %%
#Looking at where there is a difference again - finding what is best to use
df_subset = df[['Reviews_lemmatized', 'Word_Count_lemmatized_Reviews', 
                'Reviews_cleaned_wo_char_length_2', 'Word_Count_cleaned_Reviews_wo_char_length_2']]

df_subset['Diff'] = df_subset['Word_Count_lemmatized_Reviews'] - \
                    df_subset['Word_Count_cleaned_Reviews_wo_char_length_2']


df_subset = df_subset[(df_subset["Diff"] != 0)]
#df_subset = df_subset.sort_values(by='Diff', ascending=False)
df_subset.head().T
# Out:
#                                                            7   \
# Reviews_lemmatized              ever since become chef alw...
# Word_Count_lemmatized_Reviews                              26
# Reviews_cleaned_wo_char_len...  ever since become chef alw...
# Word_Count_cleaned_Reviews_...                             25
# Diff                                                        1
#
#                                                            35  \
# Reviews_lemmatized              must non expensive ovens s...
# Word_Count_lemmatized_Reviews                              13
# Reviews_cleaned_wo_char_len...  must non expensive ovens s...
# Word_Count_cleaned_Reviews_...                             12
# Diff                                                        1
#
#                                                            44  \
# Reviews_lemmatized              hard time find qt steamer ...
# Word_Count_lemmatized_Reviews                              17
# Reviews_cleaned_wo_char_len...  hard time find steamer loc...
# Word_Count_cleaned_Reviews_...                             16
# Diff                                                        1
#
#                                                            47  \
# Reviews_lemmatized              product perfect lunch take...
# Word_Count_lemmatized_Reviews                              62
# Reviews_cleaned_wo_char_len...  product perfect lunch take...
# Word_Count_cleaned_Reviews_...                             61
# Diff                                                        1
#
#                                                            63
# Reviews_lemmatized              stuff work great fryer has...
# Word_Count_lemmatized_Reviews                              15
# Reviews_cleaned_wo_char_len...  stuff work great fryer has...
# Word_Count_cleaned_Reviews_...                             14
# Diff                                                        1

# %%
#Defining some more functions
def token_and_unique_word_count_func(text):
    '''
    Outputs the number of words and unique words
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Uses the FreqDist function to count unique words
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Prints:
        Number of existing tokens and number of unique words
    ''' 
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    
    print('Number of tokens: ' + str(len(words))) 
    print('Number of unique words: ' + str(len(fdist)))

# %%
def most_common_word_func(text, n_words=25):
    '''
    Returns a DataFrame with the most commonly used words from a text with their frequencies
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Uses the FreqDist function to determine the word frequency
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        A DataFrame with the most commonly occurring words (by default = 25) with their frequencies
    ''' 
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    
    n_words = n_words
    
    df_fdist = pd.DataFrame({'Word': fdist.keys(),
                             'Frequency': fdist.values()})
    df_fdist = df_fdist.sort_values(by='Frequency', ascending=False).head(n_words)
    
    return df_fdist

# %%
def least_common_word_func(text, n_words=25):
    '''
    Returns a DataFrame with the least commonly used words from a text with their frequencies
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Uses the FreqDist function to determine the word frequency
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        A DataFrame with the least commonly occurring words (by default = 25) with their frequencies
    ''' 
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    
    n_words = n_words
    
    df_fdist = pd.DataFrame({'Word': fdist.keys(),
                             'Frequency': fdist.values()})
    df_fdist = df_fdist.sort_values(by='Frequency', ascending=False).tail(n_words)
    
    return df_fdist

# %%
#Adding in a separator
text_corpus = df['Reviews_cleaned_wo_single_char'].str.cat(sep=' ')

#text_corpus

# %%
#Seeing the number of tokens and unique words - done through our function we already created
token_and_unique_word_count_func(text_corpus)
# Out:
# Number of tokens: 45636
# Number of unique words: 4488

# %%
#Looking at the most common words and how many times they appear

df_most_common_words_text_corpus = most_common_word_func(text_corpus)

df_most_common_words_text_corpus.head(10)
# Out:
#         Word  Frequency
# 71       use       1125
# 15     great        599
# 142     good        595
# 113  product        487
# 10     would        453
# 42     price        436
# 1       like        413
# 16      work        386
# 199      get        369
# 36       one        367

# %%
#Creating a bar chart to look at this in another way
plt.figure(figsize=(11,7))
plt.bar(df_most_common_words_text_corpus['Word'], 
        df_most_common_words_text_corpus['Frequency'])

plt.xticks(rotation = 45)

plt.xlabel('Most common Words')
plt.ylabel("Frequency")
plt.title("Frequency distribution of the 25 most common words")

plt.show()

# %%
#Now looking at the least common words
df_least_common_words_text_corpus = least_common_word_func(text_corpus, n_words=10)

df_least_common_words_text_corpus
# Out:
#              Word  Frequency
# 2605       chunky          1
# 2609          moe          1
# 2623      warrant          1
# 2610         tart          1
# 2615   casseroles          1
# 2617      regency          1
# 2618  utilitarian          1
# 2619          pag          1
# 2622         dose          1
# 4487  inexcusable          1

# %%
#Creating a bar chart to look at it in another way
plt.figure(figsize=(11,7))
plt.bar(df_least_common_words_text_corpus['Word'], 
        df_least_common_words_text_corpus['Frequency'])

plt.xticks(rotation = 45)

plt.xlabel('Least common Words')
plt.ylabel("Frequency")
plt.title("Frequency distribution of the 10 least common words")

plt.show()

#Obviously this bar chart was not helpful since they were all used only once - it might be helpful to find where there is more than one or not use a bar chart

# %%
#Looking at how many we have in our sample dataset
df['Rating'].value_counts()
# Out:
# 5    500
# 4    500
# 3    500
# 2    500
# 1    500
# Name: Rating, dtype: int64

# %%
#creating a function to label our ratings as postive or negative to see how they compare to our NLP model
def label_func(rating):
    if rating <= 2:
        return 'negative'
    if rating >= 4:
        return 'positive'
    else:
        return 'neutral'

df['Label'] = df['Rating'].apply(label_func)

# %%
#Creating a list of all the columns and getting only what we need
cols = list(df.columns)
cols = [cols[-1]] + cols[:-1]
df = df[cols]

# %%
#Defining which are positive, negative, or neutral based on their star rating
positive_review = df[(df["Label"] == 'positive')]['Reviews_cleaned_wo_single_char']
neutral_review = df[(df["Label"] == 'neutral')]['Reviews_cleaned_wo_single_char']
negative_review = df[(df["Label"] == 'negative')]['Reviews_cleaned_wo_single_char']

# %%
#Adding a separator
text_corpus_positive_review = positive_review.str.cat(sep=' ')
text_corpus_neutral_review = neutral_review.str.cat(sep=' ')
text_corpus_negative_review = negative_review.str.cat(sep=' ')

# %%
#Seeing the most common words in each of them
df_most_common_words_text_corpus_positive_review = most_common_word_func(text_corpus_positive_review)
df_most_common_words_text_corpus_neutral_review = most_common_word_func(text_corpus_neutral_review)
df_most_common_words_text_corpus_negative_review = most_common_word_func(text_corpus_negative_review)

# %%
#Creating a bar chart with the most common words only for the positive/neutral/negative reviews - to help understand what is considered positive by star rating
splited_data = [df_most_common_words_text_corpus_positive_review,
                df_most_common_words_text_corpus_neutral_review,
                df_most_common_words_text_corpus_negative_review]

color_list = ['green', 'red', 'cyan']
title_list = ['Positive Review', 'Neutral Review', 'Negative Review']


for item in range(3):
    plt.figure(figsize=(11,7))
    plt.bar(splited_data[item]['Word'], 
            splited_data[item]['Frequency'],
            color=color_list[item])
    plt.xticks(rotation = 45)
    plt.xlabel('Most common Words')
    plt.ylabel("Frequency")
    plt.title("Frequency distribution of the 25 most common words")
    plt.suptitle(title_list[item], fontsize=15)
    plt.show()

# %%
#Defining some more functions

def single_word_remove_func(text, word_2_remove):
    '''
    Removes a specific word from string, if present
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Removes the defined word from the created tokens
    
    Args:
        text (str): String to which the functions are to be applied, string
        word_2_remove (str): Word to be removed from the text, string
    
    Returns:
        String with removed words
    '''    
    word_to_remove = word_2_remove
    
    words = word_tokenize(text)
    text = ' '.join([word for word in words if word != word_to_remove])
    return text

# %%
def multiple_word_remove_func(text, words_2_remove_list):
    '''
    Removes certain words from string, if present
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Removes the defined words from the created tokens
    
    Args:
        text (str): String to which the functions are to be applied, string
        words_2_remove_list (list): Words to be removed from the text, list of strings
    
    Returns:
        String with removed words
    '''     
    words_to_remove_list = words_2_remove_list
    
    words = word_tokenize(text)
    text = ' '.join([word for word in words if word not in words_to_remove_list])
    return text

# %%
def most_freq_word_func(text, n_words=5):
    '''
    Returns the most frequently used words from a text
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Uses the FreqDist function to determine the word frequency
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        List of the most frequently occurring words (by default = 5)
    ''' 
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    
    df_fdist = pd.DataFrame({'Word': fdist.keys(),
                             'Frequency': fdist.values()})
    df_fdist = df_fdist.sort_values(by='Frequency', ascending=False)
    
    n_words = n_words
    most_freq_words_list = list(df_fdist['Word'][0:n_words])
    
    return most_freq_words_list

# %%
def most_rare_word_func(text, n_words=5):
    '''
    Returns the most rarely used words from a text
    
    Step 1: Use word_tokenize() to get tokens from string
    Step 2: Uses the FreqDist function to determine the word frequency
    
    Args:
        text (str): String to which the functions are to be applied, string
    
    Returns:
        List of the most rarely occurring words (by default = 5)
    ''' 
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    
    df_fdist = pd.DataFrame({'Word': fdist.keys(),
                             'Frequency': fdist.values()})
    df_fdist = df_fdist.sort_values(by='Frequency', ascending=False)
    
    n_words = n_words
    most_rare_words_list = list(df_fdist['Word'][-n_words:])
    
    return most_rare_words_list

# %%
#Creating another bar chart to see the frequency distribution with the most common words
plt.figure(figsize=(11,7))
plt.bar(df_most_common_words_text_corpus['Word'], 
        df_most_common_words_text_corpus['Frequency'])

plt.xticks(rotation = 45)

plt.xlabel('Most common Words')
plt.ylabel("Frequency")
plt.title("Frequency distribution of the 25 most common words")

plt.show()

# %%
#Viewing the top 5 in a table
df_most_common_words_text_corpus.head()
# Out:
#         Word  Frequency
# 71       use       1125
# 15     great        599
# 142     good        595
# 113  product        487
# 10     would        453

# %%
#Creating a bar chart for the least common - again not efficient
plt.figure(figsize=(11,7))
plt.bar(df_least_common_words_text_corpus['Word'], 
        df_least_common_words_text_corpus['Frequency'])

plt.xticks(rotation = 45)

plt.xlabel('Least common Words')
plt.ylabel("Frequency")
plt.title("Frequency distribution of the 10 least common words")

plt.show()

# %%
#viewing the least common words in a table

df_least_common_words_text_corpus.tail()
# Out:
#              Word  Frequency
# 2617      regency          1
# 2618  utilitarian          1
# 2619          pag          1
# 2622         dose          1
# 4487  inexcusable          1

# %%
#Applying another function
df["Reviews_cleaned_wo_specific_word"] = df.apply(lambda x: single_word_remove_func(x["Reviews_cleaned_wo_single_char"], 
                                                            "use"), axis = 1)

# %%
#Looking at the effect of the function
text_corpus_original = df['Reviews_cleaned_wo_single_char'].str.cat(sep=' ')
text_corpus_wo_specific_word = df['Reviews_cleaned_wo_specific_word'].str.cat(sep=' ')

print('Number of words (bevore single word removal): ' + str(word_count_func(text_corpus_original)))
print('Number of words (after single word removal): ' + str(word_count_func(text_corpus_wo_specific_word)))
print()
print('Diff: ' + str(word_count_func(text_corpus_original) - word_count_func(text_corpus_wo_specific_word)))
# Out:
# Number of words (bevore single word removal): 45636
# Number of words (after single word removal): 44511
#
# Diff: 1125

# %%
#applying function
df["Reviews_cleaned_wo_specific_word"] = df.apply(lambda x: multiple_word_remove_func(x["Reviews_cleaned_wo_specific_word"], 
                                                         ["product", "item"]), axis = 1)

# %%
#Looking at effect of function
text_corpus_wo_specific_words = df['Reviews_cleaned_wo_specific_words'].str.cat(sep=' ')

print('Number of words (bevore multiple word removal): ' + str(word_count_func(text_corpus_wo_specific_word)))
print('Number of words (after multiple word removal): ' + str(word_count_func(text_corpus_wo_specific_words)))
print()
print('Diff: ' + str(word_count_func(text_corpus_wo_specific_word) - word_count_func(text_corpus_wo_specific_words)))
# Out:
# Number of words (bevore multiple word removal): 44511
# Number of words (after multiple word removal): 43799
#
# Diff: 712

# %%
#Applying function
df.apply(lambda x: single_word_remove_func(x["Reviews_cleaned_wo_single_char"], 
                                                            "use"), axis = 1)
# Out:
# 0       really like mahogany color...
# 1       superb fryer company great...
# 2       read knife americastestkit...
# 3              spoon nice weight feel
# 4               dripless great candle
#                     ...
# 2495    disappoint tablecloth look...
# 2496    order dozens november baby...
# 2497    order dozens november baby...
# 2498    order dozens november baby...
# 2499    disappoint tablecloth look...
# Length: 2500, dtype: object

# %%
df.apply(lambda x: multiple_word_remove_func(x["Reviews_cleaned_wo_specific_word"], 
                                                         ["product", "item"]), axis = 1)
# Out:
# 0       really like mahogany color...
# 1       superb fryer company great...
# 2       read knife americastestkit...
# 3              spoon nice weight feel
# 4               dripless great candle
#                     ...
# 2495    disappoint tablecloth look...
# 2496    order dozens november baby...
# 2497    order dozens november baby...
# 2498    order dozens november baby...
# 2499    disappoint tablecloth look...
# Length: 2500, dtype: object

# %%
#Viewing the current data frame
df.head()
# Out:
#       Label  Rating                         Review  \
# 0  positive       5  I really like how the maho...
# 1  positive       5  What a superb fryer! Your ...
# 2  positive       5  I read about this knife at...
# 3  positive       5  The spoons have a nice wei...
# 4  positive       5        Dripless, great candle!
#
#                    Clean_Reviews  Word_Count              Reviews_Tokenized  \
# 0  i really like how the maho...          27  [i, really, like, how, the...
# 1  what a superb fryer your c...          27  [what, a, superb, fryer, y...
# 2  i read about this knife at...          62  [i, read, about, this, kni...
# 3  the spoons have a nice wei...          10  [the, spoons, have, a, nic...
# 4          dripless great candle           3      [dripless, great, candle]
#
#    Token_Count          Reviews_wo_Stop_Words  Word_Count_wo_Stop_Words  \
# 0           27  really like mahogany color...                        14
# 1           27  superb fryer company great...                        12
# 2           62  read knife americastestkit...                        42
# 3           10        spoons nice weight feel                         4
# 4            3          dripless great candle                         3
#
#               Reviews_lemmatized  Word_Count_lemmatized_Reviews  \
# 0  really like mahogany color...                             14
# 1  superb fryer company great...                             12
# 2  read knife americastestkit...                             42
# 3         spoon nice weight feel                              4
# 4          dripless great candle                              3
#
#   Reviews_cleaned_wo_single_char  Word_Count_cleaned_Reviews_wo_single_char  \
# 0  really like mahogany color...                             14
# 1  superb fryer company great...                             12
# 2  read knife americastestkit...                             42
# 3         spoon nice weight feel                              4
# 4          dripless great candle                              3
#
#   Reviews_cleaned_wo_char_length_2  \
# 0  really like mahogany color...
# 1  superb fryer company great...
# 2  read knife americastestkit...
# 3         spoon nice weight feel
# 4          dripless great candle
#
#    Word_Count_cleaned_Reviews_wo_char_length_2  \
# 0                             14
# 1                             12
# 2                             42
# 3                              4
# 4                              3
#
#   Reviews_cleaned_wo_specific_word Reviews_cleaned_wo_specific_words
# 0  really like mahogany color...    really like mahogany color...
# 1  superb fryer company great...    superb fryer company great...
# 2  read knife americastestkit...    read knife americastestkit...
# 3         spoon nice weight feel           spoon nice weight feel
# 4          dripless great candle            dripless great candle

# %%
#Pulling only what we need into a final data frame
finalData = pd.DataFrame(df[['Review','Reviews_cleaned_wo_specific_word', 'Label','Rating']])

# %%
##looking at the top 5 to confirm it was done correctly
finalData.head()
# Out:
#                           Review Reviews_cleaned_wo_specific_word     Label  \
# 0  I really like how the maho...  really like mahogany color...    positive
# 1  What a superb fryer! Your ...  superb fryer company great...    positive
# 2  I read about this knife at...  read knife americastestkit...    positive
# 3  The spoons have a nice wei...         spoon nice weight feel    positive
# 4        Dripless, great candle!          dripless great candle    positive
#
#    Rating
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5

# %%
#Applying NLP functions to see the analysis of the reviews
finalData['Subjectivity'] = finalData['Reviews_cleaned_wo_specific_word'].apply(getSubjectivity) 
finalData['Polarity'] = finalData['Reviews_cleaned_wo_specific_word'].apply(getPolarity) 
finalData['Analysis'] = finalData['Polarity'].apply(analysis)

# %%
#Seeing the top 20
finalData.head(20)
# Out:
#    Reviews_cleaned_wo_specific_word     Label  Rating  Subjectivity  Polarity  \
# 0   really like mahogany color...    positive       5      0.350000  0.183333
# 1   superb fryer company great...    positive       5      0.816667  0.722222
# 2   read knife americastestkit...    positive       5      0.471944  0.057222
# 3          spoon nice weight feel    positive       5      1.000000  0.600000
# 4           dripless great candle    positive       5      0.750000  0.800000
# 5                    great candle    positive       5      0.750000  0.800000
# 6   church annual chocolate fe...    positive       5      0.561111  0.500000
# 7   ever since become chef alw...    positive       5      0.440000  0.210000
# 8   excellant inexpensive biod...    positive       5      0.550000  0.200000
# 9               great great price    positive       5      0.750000  0.800000
# 10  make best mojito barnone s...    positive       5      0.400000  0.687500
# 11  pasta dish look even good ...    positive       5      0.633333  0.900000
# 12    lids fit tight good quality    positive       5      0.428571  0.307143
# 13  great adjust size shell po...    positive       5      0.750000  0.800000
# 14  plastic heavy weight plat ...    positive       5      0.666667  0.466667
# 15  perfect coffee shop self s...    positive       5      0.697619  0.485714
# 16  freezer arrive quickly per...    positive       5      0.450000  0.550000
# 17  buy gift church kitchen ba...    positive       5      0.611111  0.600000
# 18          work great good price    positive       5      0.675000  0.750000
# 19  work well great price lids...    positive       5      0.750000  0.800000
#
#     Analysis
# 0   Positive
# 1   Positive
# 2   Positive
# 3   Positive
# 4   Positive
# 5   Positive
# 6   Positive
# 7   Positive
# 8   Positive
# 9   Positive
# 10  Positive
# 11  Positive
# 12  Positive
# 13  Positive
# 14  Positive
# 15  Positive
# 16  Positive
# 17  Positive
# 18  Positive
# 19  Positive

# %%
#Counting how many were positive, negative, and neutral
tb_counts = finalData.Analysis.value_counts()
tb_counts
# Out:
# Positive    1976
# Negative     431
# Neutral       93
# Name: Analysis, dtype: int64

# %%
#Putting the data in a form to compare
finalData.loc[finalData['Rating'] == 5, 'Comparison']='Positive'
finalData.loc[finalData['Rating'] == 4,'Comparison']='Positive'
finalData.loc[finalData['Rating'] == 3, 'Comparison']='Neutral'
finalData.loc[finalData['Rating'] == 2, 'Comparison']='Negative'
finalData.loc[finalData['Rating'] == 1, 'Comparison']='Negative'
finalData.loc[finalData['Rating'] == 0, 'Comparison']='Not Accurate'

# %%
finalData['Accuracy']=finalData['Analysis'] == finalData['Comparison']

# %%
#Setting up a graph to see the comparison
ax= finalData['Accuracy'].value_counts(sort=False).plot(kind='barh')
ax.set_xlabel("Number of Samples in training set")
ax.set_ylabel("Label")
# Out:
# Text(0, 0.5, 'Label')

# %%
#Lookng at just the counts
tb_counts = finalData.Accuracy.value_counts()
tb_counts
# Out:
# True     1262
# False    1238
# Name: Accuracy, dtype: int64

# %%
#seeing more of the reviews written out to view
text_corpus = df['Reviews_cleaned_wo_specific_word'].str.cat(sep=' ')
#text_corpus

# %%
#looking at most common words again
common = most_common_word_func(text_corpus)

common.head(10)
# Out:
#       Word  Frequency
# 15   great        599
# 139   good        595
# 10   would        453
# 42   price        436
# 1     like        413
# 16    work        386
# 196    get        369
# 36     one        367
# 710  drink        361
# 59    well        349

# %%
#Filtering to the 'false' data
filter = finalData["Accuracy"]==False
filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2495     True
# 2496     True
# 2497     True
# 2498     True
# 2499     True
# Name: Accuracy, Length: 2500, dtype: bool

# %%
#Put in a CSV to look closely at what is considered false and if it appears accurate or not
filteredData = finalData.where(filter)
filteredData.to_csv('reviewsFalse.csv', index=False)

# %%
#This project was done with different functions and models and unfortunatly I left before it was 'perfect'. 
#We found in the 'false' ones that technically they did appear accurate even though the star rating didn't match - which
#was the purpose of the project. It still can use a lot of imporvement, but we were able to find some valuable insights
#just by going through the data that we didn't have in the company before
